# %% [markdown]
# # Significant DOLE Department Orders

# %% [markdown]
# # Import libraries

# %%
import test
import pandas as pd

# %% [markdown]
# # To do list
#
# update 2: current pipeline is two fold, the first is by using the collect_link_details() and collect_content() in pair with each other to extract the link_text, href, page_header, and page_text_content values, and the second is by in part manually copying and pasting each link_text, href, page_header, and page_text_content values, by using beautiful soup to handle the sometimes bug of collect_content() functions inability to grab the headers
#
# problem 8: with the sometimes inability of collect_content() to grab the headers of different selectors even if the selector exists on the page but somehow just doesn't get grabbed, use beautiful soup to again use a css selector and grab the header/s and append them if there are in fact more than one. DONE
#
# problem 9: links may be doubled for some inconvenient and inexusable reason in that website so the solution is to collect all links with css selector, merge text of links with same href and place in a single row, merge links with same href and place in single row. PENDING

# %% [markdown]
# ![title](./returning%20indeces%20of%20rows%20with%20duplicates.png)

# %% [markdown]
# # Extract link text and link href
# page link container: html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr > td > div:first-of-type > div:nth-of-type(2) > table > tbody > tr > td > div:nth-of-type(2) > center:nth-of-type(2) > center:first-of-type > center > table > tbody

# %%
link_details = test.collect_link_details_bs(
    "https://www.chanrobles.com/significantDOLEdepartmentorders.html",
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr > td > div:first-of-type > div:nth-of-type(2) > table > tbody > tr > td > div:nth-of-type(2) > center:nth-of-type(2) > center:first-of-type > center > table > tbody"
)
# Out:
# c:\Users\Mig\Desktop\projects\RS_for_labor_related_cases\data_etl_scripts\test.py:162: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 162 of the file c:\Users\Mig\Desktop\projects\RS_for_labor_related_cases\data_etl_scripts\test.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   dom = BeautifulSoup(dom_text)

# %%
link_details
# Out:
#                                             link_text  \
# 0   Department\nOrder No. 1, (Series of 2001) [Exp...
# 1   Department\nOrder No. 2, (Series of 2001) [Gui...
# 2   Department\nOrder No. 3, (Series of 2001) [Rev...
# 3   Department\nOrder No. 4, (Series of 2001) [Med...
# 4   Department\nOrder No. 5, (Series of 2001) [Inc...
# 5   Department\nOrder No. 6, (Series of 2001) [Omn...
# 6   Department\nOrder No. 7, (Series of 2001) [Gui...
# 7   Department\nOrder No. 8, (Series of 2001) [Imp...
# 8   Department\nOrder No. 9, (Series of 2001) [Rev...
# 9   Department\nOrder No. 10, (Series of 2001) [Re...
# 10  Department\nOrder No. 11, (Series of 2001) [Re...
# 11  Department\nOrder No. 12, (Series of 2001) [Om...
# 12  Department\nOrder No. 13, (Series of 2001) [Su...
# 13  Department\nOrder No. 14, (Series of 2001) [Gu...
# 14  Department\nOrder No. 15, (Series of 2001) [Ru...
# 15  Department\nOrder No. 16, (Series of 2001) [Tr...
# ...

# %%
link_details['href'][0]
# Out:
# 'https://www.chanrobles.com/doledepartmentorderno1-2001.html'

# %% [markdown]
# # extract headers and text content
# ## 1st pass
#
# https://www.chanrobles.com/doledepartmentorderno1-2001.html
#
# header:
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2),
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3),
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type
#
# text content:
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)

# %%
page_details = test.collect_content_bs(
    link_details['href'], 
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type",
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)"    
)
# Out:
# Header:
#
# Department
# Order No. 1 (Series of 2001).
# Expansion
# of Learnable Trades
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
# Text content:
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
#
#
#
#
# Pursuant to
# Articles 60 of P.
# D. 442, as amended by Executive Order No. 111 promulgated on
# December
# 24, 1986; and the provisions of RA 7796, also known as TESDA
# Act of 1994, Rule II, Section 4 of the Implementing Rules and
# Regulations,
# and upon this recommendations of the Technical Education and Skills
# Development
# Authority (TESDA), Office of Apprenticeship (OA) the trade stated below
# with its corresponding work process and training hours is hereby
# approved
# as learnable and hereafter be made the subject of learnership by firms
# desiring to organize an appropriate program.
#
#
#
#
#
#
#
#
# PSOC
# CODE
# Trade/Occupation
# Sector
# ...

# %%
page_details
# Out:
#                                             page_link  \
# 0   https://www.chanrobles.com/doledepartmentorder...
# 1   https://www.chanrobles.com/doledepartmentorder...
# 2   https://www.chanrobles.com/doledepartmentorder...
# 3   https://www.chanrobles.com/doledepartmentorder...
# 4   https://www.chanrobles.com/doledepartmentorder...
# 5   https://www.chanrobles.com/doledepartmentorder...
# 6   https://www.chanrobles.com/doledepartmentorder...
# 7   https://www.chanrobles.com/doledepartmentorder...
# 8   https://www.chanrobles.com/doledepartmentorder...
# 9   https://www.chanrobles.com/doledepartmentorder...
# 10  https://www.chanrobles.com/doledepartmentorder...
# 11  https://www.chanrobles.com/doledepartmentorder...
# 12  https://www.chanrobles.com/doledepartmentorder...
# 13  https://www.chanrobles.com/doledepartmentorder...
# 14  https://www.chanrobles.com/doledepartmentorder...
# 15  https://www.chanrobles.com/doledepartmentorder...
# ...

# %% [markdown]
# # To do list
#
# problem 10: the problem now is yes the element does exist when grabbing it from other pages however it is an element that does not contain the text content, so the css selector used for grabbing the html element that contained the text content in one page may or may not work on other pages. PENDING

# %%
page_details['page_text_content'][10]
# Out:
# '\n\n\n\n\n\n\n\nTHE\nCHAN ROBLES VIRTUAL LAW LIBRARY - QUICK GLANCE\n\n\n\n\n\n\n\n\nPhilippines\n\n\n\n|\xa0 \n\n\nWorldwide\n\xa0\n\n|\n\n\nThe\nBusiness Page\n\n\n\n\n\n'

# %% [markdown]
# and so instead of the above text content what we can do is indicate a constraint or condition such that the page_link using the css selector is either rejected or accepted. This constraint can be if page_text_content is below a certain character count, for instance 10 then mark that link as rejected so you can see what link was it and just inspect the page again manually and identify the html element containing the content and use its css selector

# %%
len(page_details['page_text_content'][10])
# Out:
# 128

# %% [markdown]
# so threshold can be 128 inclusively as well as if it drops below it. So the redefined function will be the following

# %%
import requests
from bs4 import BeautifulSoup
from urllib.error import URLError, HTTPError

# collects and returns link, headers, and text content of page
def collect_content_bs(links: list[str], header_selector: str, text_content_selector: str, threshold: int=128) -> pd.DataFrame:
    page_headers = []
    page_text_content = []
    accepted = []
    rejects = []
    for link in links:
        try:
            # open page, and raise a URLError exception if url entered is
            # not valid, and similarly an HTTPError if the url is in fact
            # valid but the url does not exist in the server
            dom_text = requests.get(link).text
            dom = BeautifulSoup(dom_text, 'lxml')
            
            # grab html elements that contain important header content
            # exhaust the list returned by appending
            header = " ".join([element.get_text() for element in dom.select(header_selector)]) if dom.select(header_selector) != [] else None

            # display header
            print("\033[92m {}\033[00m".format("Header: {}\n".format(header)))

            # raise error if dom.select() returns empty list
            if header is None:
                raise ValueError('dom.select() returned an empty list for link {} due to header selector'.format(link))
            
            
            # grab a single html element only since it cannto be generalized 
            # across multiple pages since the structure may change and some
            # elements may not be grabbed
            text_content = dom.select_one(text_content_selector)

            # display text content
            print("\033[96m {}\033[00m".format("Text content: {}\nLength: {}\n\n".format(text_content.get_text(), len(text_content.get_text()))))

            # raise error if text dom.select_one() returns None
            if text_content is None or len(text_content.get_text()) <= threshold:
                raise ValueError('dom.select_one returned none for link due to text content selector or length of text content is below threshold'.format(link))

            # store accepted headers and text content
            page_headers.append(header)
            page_text_content.append(text_content.get_text())

            # append if no error is raised
            accepted.append(link)
            
        # raise a URLError or HTTPError if url pattern is invalid
        # or if url does not exist in the server respectively
        except (URLError, HTTPError) as error:
            print("Error: {} has occured".format(error))

        except ValueError as error:
            print("Error: {} has occured".format(error))
            rejects.append(link)

        finally:
            print("will go to next link")

    print("number of total links: {}\nnumber of accepted links: {}\nnumber of reject links: {}\n".format(len(links), len(accepted), len(rejects)))
    print("accepted links: ", accepted, end='\n')
    print("rejected links: ", rejects, end='\n')

    # place text in data frame if no error is raised
    return pd.DataFrame({'page_link': accepted, 'page_header': page_headers, 'page_text_content': page_text_content})

# %% [markdown]
# # 1st pass
#
# header: "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type",
#
# text content: "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)"

# %%
page_details = collect_content_bs(
    link_details['href'], 
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type",
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)"
)
# Out:
#  Header:
#
# Department
# Order No. 1 (Series of 2001).
# Expansion
# of Learnable Trades
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
#
#  Text content:
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
#
#
#
#
# Pursuant to
# Articles 60 of P.
# D. 442, as amended by Executive Order No. 111 promulgated on
# December
# 24, 1986; and the provisions of RA 7796, also known as TESDA
# Act of 1994, Rule II, Section 4 of the Implementing Rules and
# Regulations,
# and upon this recommendations of the Technical Education and Skills
# Development
# Authority (TESDA), Office of Apprenticeship (OA) the trade stated below
# with its corresponding work process and training hours is hereby
# approved
# as learnable and hereafter be made the subject of learnership by firms
# desiring to organize an appropriate program.
#
#
#
#
#
#
#
#
# PSOC
# CODE
# Trade/Occupation
# Sector
# ...

# %%
page_details
# Out:
#                                             page_link  \
# 0   https://www.chanrobles.com/doledepartmentorder...
# 1   https://www.chanrobles.com/doledepartmentorder...
# 2   https://www.chanrobles.com/doledepartmentorder...
# 3   https://www.chanrobles.com/doledepartmentorder...
# 4   https://www.chanrobles.com/doledepartmentorder...
# 5   https://www.chanrobles.com/doledepartmentorder...
# 6   https://www.chanrobles.com/doledepartmentorder...
# 7   https://www.chanrobles.com/doledepartmentorder...
# 8   https://www.chanrobles.com/doledepartmentorder...
# 9   https://www.chanrobles.com/doledepartmentorder...
# 10  https://www.chanrobles.com/doledepartmentorder...
# 11  https://www.chanrobles.com/doledepartmentorder...
# 12  https://www.chanrobles.com/doledepartmentorder...
# 13  https://www.chanrobles.com/dolerule1160-2001.html
#
#                                           page_header  \
# 0   \n\nDepartment\nOrder No. 1 (Series of 2001). ...
# ...

# %%
page_details['page_text_content'][3]
# Out:
# '\n\n\n\n\n\n\n\nTHE\nCHAN ROBLES VIRTUAL LAW LIBRARY - QUICK GLANCE\n\n\n\n\n\n\n\n\nPhilippines\n\n\xa0\n\n\n|\xa0 \n\n\nWorldwide\n\xa0\n\n|\n\xa0\n\n\nThe\nBusiness Page\n\n\n\n\n\n'

# %%
page_details['page_text_content'][2]
# Out:
# '\n\n\n\n\n\n\nRead\nFull Text of the Rules on Contracting and Subcontracting Arrangement:chanroblesvirtuallawlibrary\n\n\n\n\n\n\n\n\nDepartment\nOrder No. 18-02 (Series of 2002) [\n\nRules\nImplementing Articles 106 to 109 of the Labor Code, as Amended]\n\n\n\n\n\n\n\n\n\n\n\nDepartment\nOrder No. 03 (Series of 2001) [Revoking Department Order No. 10,\nSeries\nof 1997, and Continuing to Prohibit Labor-Only Contracting]\n\n\n\n\n\n\n\n\n\nDOLE\nPrimer on Contracting and Subcontracting Under Articles 106 to 109 of\nthe\nLabor Code\n\n\n\n\n\n\n\nDepartment\nOrder No. 10 (Series of 1997) [\nAmending\nthe\nRules Implementing Books III and VI of the Labor Code, as Amended]\n\n\n\n\n\n\n'

# %%
[len(length) for length in page_details['page_text_content']]
# Out:
# [9704, 133, 623, 132, 132, 132, 132, 132, 133, 623, 132, 132, 10988, 132]

# %% [markdown]
# # 2nd pass
#
# header: html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(3) > strong:first-of-type,
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(3) > strong:nth-of-type(2),
# html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(3) > p
#
# text content: "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)"

# %%
page_details = collect_content_bs(
    link_details['href'], 
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type",
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2)",
    threshold=800
)
# Out:
#  Header:
#
# Department
# Order No. 1 (Series of 2001).
# Expansion
# of Learnable Trades
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
#
#  Text content:
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 1
#
#
# (Series of 2001)
#
#
# EXPANSION
# OF LEARNABLE TRADES
#
#
#
#
#
#
# Pursuant to
# Articles 60 of P.
# D. 442, as amended by Executive Order No. 111 promulgated on
# December
# 24, 1986; and the provisions of RA 7796, also known as TESDA
# Act of 1994, Rule II, Section 4 of the Implementing Rules and
# Regulations,
# and upon this recommendations of the Technical Education and Skills
# Development
# Authority (TESDA), Office of Apprenticeship (OA) the trade stated below
# with its corresponding work process and training hours is hereby
# approved
# as learnable and hereafter be made the subject of learnership by firms
# desiring to organize an appropriate program.
#
#
#
#
#
#
#
#
# PSOC
# CODE
# Trade/Occupation
# Sector
# ...

# %%
page_details
# Out:
#                                            page_link  \
# 0  https://www.chanrobles.com/doledepartmentorder...
# 1  https://www.chanrobles.com/doledepartmentorder...
#
#                                          page_header  \
# 0  \n\nDepartment\nOrder No. 1 (Series of 2001). ...
# 1  \n\nDepartment\nOrder No. 53-03 (Series of 200...
#
#                                    page_text_content
# 0  \n\n\n\n\n\n\n\nDEPARTMENT\nORDER NO. 1\n\n\n(...
# 1  \n\n\n\n\n\n\n\nDEPARTMENT\nORDER NO. 53-03\n\...

# %%
page_details['page_text_content'][1]
# Out:
# '\n\n\n\n\n\n\n\nDEPARTMENT\nORDER NO. 53-03\n\n\n(Series of 2003)\n\n\xa0\nGUIDELINES\nFOR THE IMPLEMENTATION OF A DRUG-FREE WORKPLACE POLICIES AND PROGRAMS\nFOR\nTHE PRIVATE SECTOR\n\n\n\n\n\n\n\n\n\n\nIn accordance\nwith Article V of Republic\nAct No. 9165, otherwise known as the Comprehensive Dangerous Drug Act\nof\n2002, and its Implementing Rules and Regulations and in\nconsultation\nwith the Tripartite Task Force Created under DOLE Department Order No.\n37-03, s. 2003 (Tripartite Task Force), the following guidelines are\nhereby\nissued to assist employers and employees in the formulation of company\npolicies and programs to achieve a drug-free workplace.\n\n\nA. COVERAGE\n\n\n\n1.\nThe guidelines shall apply to all establishments in private sector,\nincluding\ntheir contractors and concessionaires\n\nB. FORMULATION\nOF DRUG-FREE WORKPLACE POLICIES AND PROGRAMS\n\n1.\nIt shall be mandatory for all private establishments employing ten (10)\nor more workers to formulate and impl
# ...

# %%
[len(page_text_content) for page_text_content in page_details['page_text_content']]
# Out:
# [9704, 10988]

# %% [markdown]
# # 3rd pass
#
# header: "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type"
#
# text content: html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center

# %%
page_details = pd.concat([page_details.copy(), collect_content_bs(
    ['https://www.chanrobles.com/doledepartmentorderno2-2001.html', 'https://www.chanrobles.com/doledepartmentorderno03-2001.html', 'https://www.chanrobles.com/doledepartmentorderno4-2001.html', 'https://www.chanrobles.com/doledepartmentorderno5-2001.html', 'https://www.chanrobles.com/doledepartmentorderno6-2001.html', 'https://www.chanrobles.com/doledepartmentorderno7-2001.html', 'https://www.chanrobles.com/doledepartmentorderno8-2001.html', 'https://www.chanrobles.com/doledepartmentorderno9-2001.html', 'https://www.chanrobles.com/doledepartmentorderno10-2001.html', 'https://www.chanrobles.com/doledepartmentorderno11-2001.html', 'https://www.chanrobles.com/doledepartmentorderno12-2001.html', 'https://www.chanrobles.com/doledepartmentorderno13-2001.html', 'https://www.chanrobles.com/doledepartmentorderno14-2001.html', 'https://www.chanrobles.com/doledepartmentorderno15-2001.html', 'https://www.chanrobles.com/doledepartmentorderno16-2001.html', 'https://www.chanrobles.com/dolerule1160-2001.html', 'https://www.chanrobles.com/dolerule1170-2001.html'], 
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(2), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:first-of-type > strong:nth-of-type(3), html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center > center:nth-of-type(2) > center:first-of-type",
    "html > body > div:first-of-type > div:nth-of-type(2) > div > div:nth-of-type(5) > div > table > tbody > tr:first-of-type > td > div > div:first-of-type > div > table > tbody > tr > td > div:nth-of-type(2) > center",
    threshold=800
)], ignore_index=True)
# Out:
#  Header:
#
# Department
# Order No. 2 (Series of 2001).
#
#
#
#
#
#
# THE
# CHAN ROBLES VIRTUAL LAW LIBRARY - QUICK GLANCE
#
#
#
#
#
#
#
#
# Philippines
#
#
#
#
# |
#
#
# Worldwide
#
#
# |
#
#
#
# The
# Business Page
#
#
#
#
#
#
#  Text content:
#
#
#
#
#
#
#
#
#
#
#
#
#
# This web page
# features
# the full text of
#
#
# Department
# Order No. 2 (Series of 2001).
#
#
# Guidelines
# For the Conduct of Jobs Fair By Private Entities, Non-Government
# Organizations
# and Educational Institutions.chanrobles virtual law library
#
#
#
#
#
#
#
#
#
#
#
#
#
# THE
# CHAN ROBLES VIRTUAL LAW LIBRARY - QUICK GLANCE
#
#
#
#
#
#
#
#
# Philippines
#
#
#
#
# |
#
#
# Worldwide
#
#
# |
#
#
#
# The
# Business Page
#
#
#
#
#
#
#
#
#
#
#
#
#
# DEPARTMENT
# ORDER NO. 2
#
#
# (Series of 2001)
#
#
# GUIDELINES
# FOR THE CONDUCT OF JOBS FAIR BY PRIVATE ENTITIES, NON-GOVERNMENT
# ORGANIZATIONS
# AND EDUCATIONAL INSTITUTIONS.
#
#
#
#
#
#
#
#
#
# In line with the
# ...

# %%
page_details
# Out:
#                                             page_link  \
# 0   https://www.chanrobles.com/doledepartmentorder...
# 1   https://www.chanrobles.com/doledepartmentorder...
# 2   https://www.chanrobles.com/doledepartmentorder...
# 3   https://www.chanrobles.com/doledepartmentorder...
# 4   https://www.chanrobles.com/doledepartmentorder...
# 5   https://www.chanrobles.com/doledepartmentorder...
# 6   https://www.chanrobles.com/doledepartmentorder...
# 7   https://www.chanrobles.com/doledepartmentorder...
# 8   https://www.chanrobles.com/doledepartmentorder...
# 9   https://www.chanrobles.com/doledepartmentorder...
# 10  https://www.chanrobles.com/doledepartmentorder...
# 11  https://www.chanrobles.com/doledepartmentorder...
# 12  https://www.chanrobles.com/doledepartmentorder...
# 13  https://www.chanrobles.com/doledepartmentorder...
# 14  https://www.chanrobles.com/doledepartmentorder...
# 15  https://www.chanrobles.com/doledepartmentorder...
# ...

# %%
[len(page_text_content) for page_text_content in page_details['page_text_content']]
# Out:
# [9704,
#  10988,
#  11505,
#  3121,
#  1418,
#  1729,
#  8705,
#  6657,
#  3701,
#  12186,
#  9269,
#  1072,
#  9696,
#  1777,
#  24439,
#  22275,
#  19458,
#  44535,
#  37337]

# %% [markdown]
# # Export DataFrame to excel

# %%
link_details.to_csv('Significant DOLE Department Orders link details data.csv')
page_details.to_csv('Significant DOLE Department Orders page details data.csv')

# %% [markdown]
# problem 11: when exporting the DataFrame object for some reason some row values of the page_text_content column does not contain all the text and gets cut off at a certain character count. What may be the problem for this? And also this may be a problem for every file Major Philippine Labor Law Resources, NLRC, 13th Month Pay Law, Rules on Contracting Arrangement, and Significant DOLE Department Orders. PENDING
